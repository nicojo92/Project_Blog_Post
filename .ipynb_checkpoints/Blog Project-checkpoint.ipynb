# %% [markdown]
# # Blog Project

# %% [markdown]
# ## Objective

# %% [markdown]
# Here I will explain the objective of the project.

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# Here I will give infos to the dataset that will be used, such as the source and an overview of th features and targets.

# %% [markdown]
# ## Import Libraries

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# Model imports (e.g., logistic regression, random forest, etc.)
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Load Dataset & Exploratory Data Analysis

# %% [markdown]
# ### Load Dataset

# %%
# Load data
df_survey = pd.read_csv('data/survey_results_public.csv')

# Divide data into numerical and categorical data types
df_survey_num = df_survey.select_dtypes(include="number")
df_survey_cat = df_survey.select_dtypes(include="object")

# Show all columns when Data Frames are beeing visualised
pd.set_option('display.max_columns', None)

# %% [markdown]
# ### Data Structure & Overview

# %%
# Dataset summary
print("Info: ")
df_survey.info()

# Shape of the dataset
print("\nShape: ", df_survey.shape)

# Column names
print("\nColumns: ", df_survey.columns)

# First rows of the dataset
print("\nFirst two rows: \n", df_survey.head(2))
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 65437 entries, 0 to 65436
# Columns: 114 entries, ResponseId to JobSat
# dtypes: float64(13), int64(1), object(100)
# memory usage: 56.9+ MB
#
# Shape:  (65437, 114)
#
# Columns:  Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)
#
# First two rows:
#     ResponseId                      MainBranch                 Age  \
# 0           1  I am a developer by profession  Under 18 years old
# 1           2  I am a developer by profession     35-44 years old
#
#             Employment RemoteWork   Check  \
# 0  Employed, full-time     Remote  Apples
# ...

# %% [markdown]
# ### Summary Statistics

# %%
# Summary statistics of numerical data
print("Numerical Data: \n", df_survey.describe())

# Summary statistics of categorical data
print("\nCategorical Data: \n", df_survey.describe(include=['object']))
# Out:
# Numerical Data:
#           ResponseId      CompTotal       WorkExp  JobSatPoints_1  \
# count  65437.000000   3.374000e+04  29658.000000    29324.000000
# mean   32719.000000  2.963841e+145     11.466957       18.581094
# std    18890.179119  5.444117e+147      9.168709       25.966221
# min        1.000000   0.000000e+00      0.000000        0.000000
# 25%    16360.000000   6.000000e+04      4.000000        0.000000
# 50%    32719.000000   1.100000e+05      9.000000       10.000000
# 75%    49078.000000   2.500000e+05     16.000000       22.000000
# max    65437.000000  1.000000e+150     50.000000      100.000000
#
#        JobSatPoints_4  JobSatPoints_5  JobSatPoints_6  JobSatPoints_7  \
# count    29393.000000    29411.000000    29450.000000     29448.00000
# mean         7.522140       10.060857       24.343232        22.96522
# std         18.422661       21.833836       27.089360        27.01774
# min          0.000000        0.000000        0.000000         0.00000
# ...

# %% [markdown]
# ### Missing Values

# %%
# Check for missing values
pd.set_option('display.max_rows', None)
print(df_survey.isnull().sum().sort_values(ascending=False))
pd.reset_option('display.max_rows')
# Out:
# AINextMuch less integrated        64289
# AINextLess integrated             63082
# AINextNo change                   52939
# AINextMuch more integrated        51999
# EmbeddedAdmired                   48704
# EmbeddedWantToWorkWith            47837
# EmbeddedHaveWorkedWith            43223
# ConvertedCompYearly               42002
# AIToolNot interested in Using     41023
# AINextMore integrated             41009
# Knowledge_9                       37802
# Frequency_3                       37727
# Knowledge_8                       37679
# ProfessionalTech                  37673
# Knowledge_7                       37659
# Knowledge_6                       37573
# Knowledge_5                       37557
# Knowledge_2                       37416
# Knowledge_4                       37407
# Knowledge_3                       37342
# Frustration                       37186
# Frequency_2                       37073
# Frequency_1                       37068
# ...

# %% [markdown]
# ### Data Types

# %%
# Check data types
pd.set_option('display.max_rows', None)
print("Data types: \n", df_survey.dtypes.sort_values())
pd.reset_option('display.max_rows')
# Out:
# Data types:
#  ResponseId                          int64
# JobSatPoints_11                   float64
# JobSatPoints_10                   float64
# JobSatPoints_9                    float64
# JobSatPoints_8                    float64
# JobSatPoints_7                    float64
# JobSatPoints_6                    float64
# JobSatPoints_5                    float64
# JobSatPoints_4                    float64
# JobSatPoints_1                    float64
# WorkExp                           float64
# ConvertedCompYearly               float64
# CompTotal                         float64
# JobSat                            float64
# OrgSize                            object
# Knowledge_5                        object
# Knowledge_4                        object
# Knowledge_3                        object
# Knowledge_2                        object
# Knowledge_1                        object
# TechDoc                            object
# ICorPM                             object
# ...

# %% [markdown]
# ### Reduce Data

# %%
# Create two new data frames for numerical and categorical data with reduced columns
num_cols = ["WorkExp", "ConvertedCompYearly", "JobSat"]
cat_cols = ["MainBranch", "Age", "Employment", "EdLevel", "Country", "OrgSize", "YearsCode"]

# %%
# Examine unique values of categorical variables
for col in cat_cols:
    uniques = df_survey_cat[col].unique()
    print(f'\n{col}:\n {uniques}')
# Out:
# MainBranch:
#  ['I am a developer by profession' 'I am learning to code'
#  'I code primarily as a hobby'
#  'I am not primarily a developer, but I write code sometimes as part of my work/studies'
#  'I used to be a developer by profession, but no longer am']
#
# Age:
#  ['Under 18 years old' '35-44 years old' '45-54 years old'
#  '18-24 years old' '25-34 years old' '55-64 years old' 'Prefer not to say'
#  '65 years or older']
#
# Employment:
#  ['Employed, full-time' 'Student, full-time'
#  'Student, full-time;Not employed, but looking for work'
#  'Independent contractor, freelancer, or self-employed'
#  'Not employed, and not looking for work'
#  'Employed, full-time;Student, part-time'
#  'Employed, full-time;Independent contractor, freelancer, or self-employed'
#  'Employed, full-time;Student, full-time' 'Employed, part-time'
#  'Student, full-time;Employed, part-time'
#  'Student, part-time;Employed, part-time' 'I prefer not to say'
# ...

# %% [markdown]
# ### Univariate Analysis

# %%
# Box plots for numerical data
df_survey_num.plot(kind="box", subplots=True, layout=(2, 7), figsize=(12, 8), sharex=False, sharey=False)
plt.tight_layout()
plt.show()

# %%
# Histograms for numerical data
df_survey_num.hist(bins=30, figsize=(12, 10))
plt.tight_layout()
plt.show()

# %%
# Filter data so that it contains only values form Germany in €
df_survey_fil = df_survey[(df_survey.Country == "Germany")
                    & (df_survey.Currency == "EUR European Euro")]

# %%
# Visualize distributions
df_survey_fil.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
df_survey_fil.loc[df_survey_fil.CompTotal.notna(), ["CompTotal"]].sort_values(by="CompTotal", ascending=False)
# Out:
#        CompTotal
# 37382  1200000.0
# 57337   999999.0
# 5934    960000.0
# 25238   850000.0
# 42521   600000.0
# ...          ...
# 38779        0.0
# 21418        0.0
# 27230        0.0
# 24450        0.0
# 42996        0.0
#
# [2991 rows x 1 columns]

# %%
plt.scatter(df_survey_fil["CompTotal"], df_survey_filtered["JobSat"])
# plt.xlim(0, 100000)
plt.show
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 plt.scatter(df_survey_fil["CompTotal"], df_survey_filtered["JobSat"])
#       2 # plt.xlim(0, 100000)
#       3 plt.show
#
# NameError: name 'df_survey_filtered' is not defined

# %% [markdown]
# ## Data Cleaning & Preprocessing

# %%
plt.hist(df_survey_filtered.loc[df_survey_filtered.CompTotal < 300000, ["CompTotal"]].dropna(), bins=10)
plt.xlim(0, 300000)
plt.show()

# %%
df_survey_filtered[["CompTotal", "JobSat"]][df_survey_filtered.CompTotal > 300000]

# %%
# Correlation matrix of the numerical data
corr_matrix = df_survey_num.corr().round(2)

plt.figure(figsize=(8, 6))
sns.heatmap(corr_matrix, annot=True, cmap="coolwarm")
plt.title("Correlation Matrix")
plt.show()
