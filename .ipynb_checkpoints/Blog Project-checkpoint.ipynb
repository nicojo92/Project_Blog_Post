# %% [markdown]
# # Blog Project

# %% [markdown]
# ## Objective

# %% [markdown]
# Here I will explain the objective of the project.

# %% [markdown]
# ## Dataset Description

# %% [markdown]
# Here I will give infos to the dataset that will be used, such as the source and an overview of th features and targets.

# %% [markdown]
# ## Import Libraries

# %%
# Imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix

# Model imports (e.g., logistic regression, random forest, etc.)
from sklearn.ensemble import RandomForestClassifier

# %% [markdown]
# ## Load Dataset

# %%
# Load data
df_raw = pd.read_csv('data/survey_results_public.csv')
df_questions = pd.read_csv('data/survey_results_schema.csv')

# Set the pandas option to show all columns when data frames are beeing visualised
pd.set_option('display.max_columns', None)

# %%
# Print first rows of survey schema
print(df_questions.qname.unique())
print(df_raw.columns)
# Out:
# ['MainBranch' 'Age' 'Employment' 'RemoteWork' 'Check' 'CodingActivities'
#  'EdLevel' 'LearnCode' 'LearnCodeOnline' 'TechDoc' 'YearsCode'
#  'YearsCodePro' 'DevType' 'OrgSize' 'PurchaseInfluence' 'BuyNewTool'
#  'BuildvsBuy' 'TechEndorse' 'Country' 'Currency' 'CompTotal' 'Language'
#  'Database' 'Platform' 'Webframe' 'Embedded' 'MiscTech' 'ToolsTech'
#  'NEWCollabTools' 'OpSys' 'OfficeStackAsync' 'OfficeStackSync'
#  'AISearchDev' 'NEWSOSites' 'SOVisitFreq' 'SOAccount' 'SOPartFreq' 'SOHow'
#  'SOComm' 'AISelect' 'AISent' 'AIBen' 'AIAcc' 'AIComplex' 'AITool'
#  'AINext' 'AIThreat' 'AIEthics' 'AIChallenges' 'TBranch' 'ICorPM'
#  'WorkExp' 'Knowledge' 'Frequency' 'TimeSearching' 'TimeAnswering'
#  'Frustration' 'ProfessionalTech' 'ProfessionalCloud'
#  'ProfessionalQuestion' 'Industry' 'JobSat' 'JobSatPoints' 'SOTeamsUsage'
#  'SurveyLength' 'SurveyEase' 'Knowledge_1' 'Knowledge_2' 'Knowledge_3'
#  'Knowledge_4' 'Knowledge_5' 'Knowledge_6' 'Knowledge_7' 'Knowledge_8'
#  'Knowledge_9' 'Frequency_1' 'Frequency_2' 'Frequency_3' 'JobSatPoints_1'
#  'JobSatPoints_4' 'JobSatPoints_5' 'JobSatPoints_6' 'JobSatPoints_7'
#  'JobSatPoints_8' 'JobSatPoints_9' 'JobSatPoints_10' 'JobSatPoints_11']
# Index(['ResponseId', 'MainBranch', 'Age', 'Employment', 'RemoteWork', 'Check',
#        'CodingActivities', 'EdLevel', 'LearnCode', 'LearnCodeOnline',
#        ...
#        'JobSatPoints_6', 'JobSatPoints_7', 'JobSatPoints_8', 'JobSatPoints_9',
#        'JobSatPoints_10', 'JobSatPoints_11', 'SurveyLength', 'SurveyEase',
#        'ConvertedCompYearly', 'JobSat'],
#       dtype='object', length=114)

# %%
# Define columns to further analyse
cols_to_keep = df_questions.iloc[:8,1].to_list()
cols_to_keep.remove('Check')
cols_to_keep.extend(['ConvertedCompYearly', 'JobSat', 'Country'])
cols_to_keep
# Out:
# ['MainBranch',
#  'Age',
#  'Employment',
#  'RemoteWork',
#  'CodingActivities',
#  'EdLevel',
#  'LearnCode',
#  'ConvertedCompYearly',
#  'JobSat',
#  'Country']

# %%
# Create a new dataframe that just contains the columns above defined
df_reduced = df_raw[cols_to_keep].copy()
df_reduced.head()
# Out:
#                        MainBranch                 Age           Employment  \
# 0  I am a developer by profession  Under 18 years old  Employed, full-time
# 1  I am a developer by profession     35-44 years old  Employed, full-time
# 2  I am a developer by profession     45-54 years old  Employed, full-time
# 3           I am learning to code     18-24 years old   Student, full-time
# 4  I am a developer by profession     18-24 years old   Student, full-time
#
#   RemoteWork                                   CodingActivities  \
# 0     Remote                                              Hobby
# 1     Remote  Hobby;Contribute to open-source projects;Other...
# 2     Remote  Hobby;Contribute to open-source projects;Other...
# 3        NaN                                                NaN
# 4        NaN                                                NaN
#
#                                              EdLevel  \
# 0                          Primary/elementary school
# 1       Bachelor’s degree (B.A., B.S., B.Eng., etc.)
# 2    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)
# 3  Some college/university study without earning ...
# 4  Secondary school (e.g. American high school, G...
#
#                                            LearnCode  ConvertedCompYearly  \
# 0                             Books / Physical media                  NaN
# 1  Books / Physical media;Colleague;On the job tr...                  NaN
# 2  Books / Physical media;Colleague;On the job tr...                  NaN
# 3  Other online resources (e.g., videos, blogs, f...                  NaN
# 4  Other online resources (e.g., videos, blogs, f...                  NaN
#
#    JobSat                                            Country
# 0     NaN                           United States of America
# 1     NaN  United Kingdom of Great Britain and Northern I...
# 2     NaN  United Kingdom of Great Britain and Northern I...
# 3     NaN                                             Canada
# 4     NaN                                             Norway

# %%
# Keep the survey results of respondents who answered "I am not primarily a developer,
# but I write code sometimes as part of my work/studies" or "I am a developer by profession"
main_branch = ["I am not primarily a developer, but I write code sometimes as part of my work/studies", "I am a developer by profession"]
df_reduced = df_reduced[df_reduced.MainBranch.isin(main_branch)]

# %%
# Keep the survey results of respondents who are employed, full-time
employed_full_time = "Employed, full-time"
df_reduced = df_reduced[df_reduced.Employment == employed_full_time]

# Drop Employment as it now only contains one unique value
df_reduced.drop(columns='Employment', inplace=True)

# %% [markdown]
# ## Basic Cleaning

# %%
# Check for missing values
pd.set_option('display.max_rows', None)
print(df_reduced.isnull().sum().sort_values(ascending=False))
print(df_reduced.isnull().mean().sort_values(ascending=False))
pd.reset_option('display.max_rows')
# Out:
# ConvertedCompYearly    20107
# JobSat                 15703
# Country                 3602
# LearnCode               2531
# EdLevel                 2375
# CodingActivities         239
# RemoteWork                10
# MainBranch                 0
# Age                        0
# dtype: int64
# ConvertedCompYearly    0.533441
# JobSat                 0.416603
# Country                0.095562
# LearnCode              0.067148
# EdLevel                0.063009
# CodingActivities       0.006341
# RemoteWork             0.000265
# MainBranch             0.000000
# Age                    0.000000
# dtype: float64

# %%
# Drop rows where the target JobSat is missing
df_cleaned = df_reduced[df_reduced.JobSat.notnull()]

# Repeat check for missing values
print(df_cleaned.isnull().sum().sort_values(ascending=False))
print(df_cleaned.isnull().mean().sort_values(ascending=False))
# Out:
# ConvertedCompYearly    9446
# LearnCode                34
# CodingActivities          5
# RemoteWork                3
# MainBranch                0
# Age                       0
# EdLevel                   0
# JobSat                    0
# Country                   0
# dtype: int64
# ConvertedCompYearly    0.429559
# LearnCode              0.001546
# CodingActivities       0.000227
# RemoteWork             0.000136
# MainBranch             0.000000
# Age                    0.000000
# EdLevel                0.000000
# JobSat                 0.000000
# Country                0.000000
# dtype: float64

# %%
# Drop columns where over 70% of values are missing
# columns_to_drop = df_cleaned.columns[(df_cleaned.isnull().mean() >= 0.7)]
# df_cleaned = df_cleaned.drop(columns=columns_to_drop)

# %%
# Check shape of df_survey after dropping rows and columns
print("Before dropping: ", df_reduced.shape)
print("After dropping: ", df_cleaned.shape)
# Out:
# Before dropping:  (37693, 9)
# After dropping:  (21990, 9)

# %% [markdown]
# ## Initial EDA

# %% [markdown]
# ### Data Types

# %%
# Check data types
pd.set_option('display.max_rows', None)
print("Data types: \n", df_cleaned.dtypes.sort_values())
pd.reset_option('display.max_rows')
# Out:
# Data types:
#  ConvertedCompYearly    float64
# JobSat                 float64
# MainBranch              object
# Age                     object
# RemoteWork              object
# CodingActivities        object
# EdLevel                 object
# LearnCode               object
# Country                 object
# dtype: object

# %%
# Examine amount of unique values of categorical variables
pd.set_option('display.max_rows', None)
print(df_cleaned.select_dtypes(include='object').nunique().sort_values())
pd.reset_option('display.max_rows')
# Out:
# MainBranch            2
# RemoteWork            3
# Age                   8
# EdLevel               8
# CodingActivities     98
# Country             157
# LearnCode           363
# dtype: int64

# %%
# Identify how often the each country in column "Country" occur
count_countries = df_cleaned.Country.value_counts(normalize=True)

# Identify countries that make up less than 1% of all countries
under_one_percent = count_countries[count_countries < 0.01].index

# Reassing the identified countries to "Other" and create new column "Country_simplified"
df_cleaned["Country_simplified"] = np.where(df_cleaned.Country.isin(under_one_percent), "Other", df_cleaned.Country)

# Remove original "Country" column
df_cleaned.drop(columns=["Country"], inplace=True)

# Check value_counts
df_cleaned.Country_simplified.value_counts()
# Out:
# /var/folders/sd/m93jcv6j64j79l56mv79pfhw0000gn/T/ipykernel_91984/4012638787.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned["Country_simplified"] = np.where(df_cleaned.Country.isin(under_one_percent), "Other", df_cleaned.Country)
# /var/folders/sd/m93jcv6j64j79l56mv79pfhw0000gn/T/ipykernel_91984/4012638787.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cleaned.drop(columns=["Country"], inplace=True)
# Country_simplified
# Other                                                   5461
# United States of America                                4634
# Germany                                                 1887
# India                                                   1664
# United Kingdom of Great Britain and Northern Ireland    1367
# Ukraine                                                  839
# France                                                   775
# Canada                                                   769
# Brazil                                                   541
# Italy                                                    529
# Netherlands                                              514
# Spain                                                    493
# Poland                                                   466
# Australia                                                466
# Sweden                                                   439
# Switzerland                                              339
# Russian Federation                                       299
# Austria                                                  264
# Israel                                                   244
# Name: count, dtype: int64

# %%
# Identify columns with high cardinality
cat_cols = df_cleaned.select_dtypes(include='object')
columns_to_drop = cat_cols.columns[cat_cols.nunique() >= 20]
columns_to_drop
# Out:
# Index(['CodingActivities', 'LearnCode'], dtype='object')

# %%
# Drop columns with high cardinality and check new shape and remaining columns
df_cleaned = df_cleaned.drop(columns=columns_to_drop)

# %%
# Check new shape and remaining columns
print(df_cleaned.shape)
columns = df_cleaned.columns.to_list()
columns.sort()
print(columns)
# Out:
# (21990, 7)
# ['Age', 'ConvertedCompYearly', 'Country_simplified', 'EdLevel', 'JobSat', 'MainBranch', 'RemoteWork']

# %% [markdown]
# ### Data Structure

# %%
# Dataset summary
print("Info: ")
df_cleaned.info()

# Shape of the dataset
print("\nShape: ", df_cleaned.shape)

# Column names
columns = df_cleaned.columns.to_list()
print("\nColumns: ", columns)

# First rows of the dataset
print("\nFirst two rows: \n", df_cleaned.head(2))
# Out:
# Info:
# <class 'pandas.core.frame.DataFrame'>
# Index: 21990 entries, 12 to 65412
# Data columns (total 7 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   MainBranch           21990 non-null  object
#  1   Age                  21990 non-null  object
#  2   RemoteWork           21987 non-null  object
#  3   EdLevel              21990 non-null  object
#  4   ConvertedCompYearly  12544 non-null  float64
#  5   JobSat               21990 non-null  float64
#  6   Country_simplified   21990 non-null  object
# dtypes: float64(2), object(5)
# memory usage: 1.3+ MB
#
# Shape:  (21990, 7)
#
# Columns:  ['MainBranch', 'Age', 'RemoteWork', 'EdLevel', 'ConvertedCompYearly', 'JobSat', 'Country_simplified']
#
# First two rows:
#                          MainBranch              Age  \
# 12  I am a developer by profession  35-44 years old
# 15  I am a developer by profession  45-54 years old
#
#                               RemoteWork  \
# 12  Hybrid (some remote, some in-person)
# 15  Hybrid (some remote, some in-person)
#
#                                               EdLevel  ConvertedCompYearly  \
# 12       Bachelor’s degree (B.A., B.S., B.Eng., etc.)                  NaN
# 15  Some college/university study without earning ...                  NaN
#
#     JobSat        Country_simplified
# 12     8.0  United States of America
# 15     5.0               Switzerland

# %% [markdown]
# ### Summary Statistics

# %%
df_cleaned.Age.unique()
# Out:
# array(['35-44 years old', '45-54 years old', '25-34 years old',
#        '55-64 years old', '18-24 years old', '65 years or older',
#        'Under 18 years old', 'Prefer not to say'], dtype=object)

# %%
# Summary statistics of numerical data
print("Numerical Data: \n", df_cleaned.describe())

# Summary statistics of categorical data
print("\nCategorical Data: \n", df_cleaned.describe(include=['object']))
# Out:
# Numerical Data:
#         ConvertedCompYearly        JobSat
# count         1.254400e+04  21990.000000
# mean          8.942110e+04      6.931060
# std           1.435716e+05      2.063386
# min           1.000000e+00      0.000000
# 25%           3.866600e+04      6.000000
# 50%           7.000000e+04      7.000000
# 75%           1.120000e+05      8.000000
# max           9.000000e+06     10.000000
#
# Categorical Data:
#                              MainBranch              Age  \
# count                            21990            21990
# unique                               2                8
# top     I am a developer by profession  25-34 years old
# freq                             20668            10109
#
#                                   RemoteWork  \
# count                                  21987
# unique                                     3
# top     Hybrid (some remote, some in-person)
# freq                                    9784
#
#                                              EdLevel Country_simplified
# count                                          21990              21990
# unique                                             8                 19
# top     Bachelor’s degree (B.A., B.S., B.Eng., etc.)              Other
# freq                                           10319               5461

# %% [markdown]
# ## Deeper EDA

# %% [markdown]
# ### Univariate Analysis (Numerical)

# %%
# Box plots for numerical data
df_cleaned.plot(kind="box", subplots=True, layout=(2, 7), figsize=(12, 8), sharex=False, sharey=False)
plt.tight_layout()
plt.show()

# %%
# Identify outliers with the method interquartile range (IQR)
lower_bound = df_cleaned.ConvertedCompYearly.quantile(0.01)
upper_bound = df_cleaned.ConvertedCompYearly.quantile(0.99)
outliers = df_cleaned[(df_cleaned.ConvertedCompYearly < lower_bound) | (df_cleaned.ConvertedCompYearly > upper_bound)]
outliers
# Out:
#                            MainBranch              Age  \
# 529    I am a developer by profession  25-34 years old
# 545    I am a developer by profession  35-44 years old
# 594    I am a developer by profession  25-34 years old
# 828    I am a developer by profession  35-44 years old
# 883    I am a developer by profession  45-54 years old
# ...                               ...              ...
# 40277  I am a developer by profession  25-34 years old
# 40353  I am a developer by profession  25-34 years old
# 40872  I am a developer by profession  35-44 years old
# 40985  I am a developer by profession  25-34 years old
# 41106  I am a developer by profession  25-34 years old
#
#                                  RemoteWork  \
# 529                               In-person
# 545                                  Remote
# 594                               In-person
# 828    Hybrid (some remote, some in-person)
# 883                                  Remote
# ...                                     ...
# 40277  Hybrid (some remote, some in-person)
# 40353  Hybrid (some remote, some in-person)
# 40872                                Remote
# 40985                                Remote
# 41106                                Remote
#
#                                                  EdLevel  ConvertedCompYearly  \
# 529         Bachelor’s degree (B.A., B.S., B.Eng., etc.)             650000.0
# 545    Secondary school (e.g. American high school, G...             400000.0
# 594         Bachelor’s degree (B.A., B.S., B.Eng., etc.)             432000.0
# 828      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)            1000000.0
# 883      Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                413.0
# ...                                                  ...                  ...
# 40277       Bachelor’s degree (B.A., B.S., B.Eng., etc.)                  5.0
# 40353    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                  1.0
# 40872    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                 63.0
# 40985       Bachelor’s degree (B.A., B.S., B.Eng., etc.)                 45.0
# 41106    Master’s degree (M.A., M.S., M.Eng., MBA, etc.)                148.0
#
#        JobSat        Country_simplified
# 529       6.0  United States of America
# 545       8.0  United States of America
# 594       8.0  United States of America
# 828       8.0  United States of America
# 883       8.0                     Other
# ...       ...                       ...
# 40277     6.0                     Other
# 40353     6.0                   Germany
# 40872     8.0                     Other
# 40985     3.0                     Other
# 41106     8.0                   Ukraine
#
# [251 rows x 7 columns]

# %%
# Visualize distributions with histograms
df_cleaned.hist(bins=30, figsize=(15, 10))
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Univariate Analysis (Categorical)

# %%
# Select categorical columns
cat_columns = df_cleaned.select_dtypes(include='object').columns

# Plot countplots for each categorical column
for col in cat_columns:
    plt.figure(figsize=(10, 4))
    sns.countplot(x=col, data=df_cleaned, order=df_cleaned[col].value_counts().index)
    plt.xticks(rotation=45, ha='right')
    plt.tight_layout()
    plt.show()
# Out:
# /var/folders/sd/m93jcv6j64j79l56mv79pfhw0000gn/T/ipykernel_91984/3364228715.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()
# /var/folders/sd/m93jcv6j64j79l56mv79pfhw0000gn/T/ipykernel_91984/3364228715.py:9: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %% [markdown]
# ### Bivariate Analysis (Numerical)

# %%
# Correlation matrix
sns.heatmap(df_red.corr(numeric_only=True), annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
# Scatter plots
sns.pairplot(df_red)
plt.show()

# %%
### Bivariate Analysis (Categorical)

# %%
cross_tab = pd.crosstab(df_cleaned['MainBranch'], df_cleaned['JobSat'], normalize='index')
cross_tab.plot(kind='bar', stacked=True, figsize=(8,4), colormap='Set2')
plt.title('JobSat distribution by MainBranch')
plt.ylabel('Proportion')
plt.xticks(rotation=45)
plt.legend(title='JobSat', bbox_to_anchor=(1.05, 1))
plt.tight_layout()
plt.show()
# Out:
# /var/folders/sd/m93jcv6j64j79l56mv79pfhw0000gn/T/ipykernel_91984/3306702038.py:7: UserWarning: Tight layout not applied. The bottom and top margins cannot be made large enough to accommodate all Axes decorations.
#   plt.tight_layout()

# %%
pd.crosstab(df_cleaned['MainBranch'], df_cleaned['JobSat'], normalize='index')
# Out:
# JobSat                                                  0.0       1.0   \
# MainBranch
# I am a developer by profession                      0.010161  0.008612
# I am not primarily a developer, but I write cod...  0.012103  0.015129
#
# JobSat                                                  2.0       3.0   \
# MainBranch
# I am a developer by profession                      0.026127  0.040304
# I am not primarily a developer, but I write cod...  0.025719  0.040091
#
# JobSat                                                  4.0       5.0   \
# MainBranch
# I am a developer by profession                      0.036965  0.064399
# I am not primarily a developer, but I write cod...  0.046142  0.105144
#
# JobSat                                                  6.0       7.0   \
# MainBranch
# I am a developer by profession                      0.127637  0.225227
# I am not primarily a developer, but I write cod...  0.157337  0.210287
#
# JobSat                                                  8.0       9.0   \
# MainBranch
# I am a developer by profession                      0.261128  0.128266
# I am not primarily a developer, but I write cod...  0.226172  0.093797
#
# JobSat                                                  10.0
# MainBranch
# I am a developer by profession                      0.071173
# I am not primarily a developer, but I write cod...  0.068079

# %% [markdown]
# ## Data Preparation

# %%
print("Before dropping outliers: ", df_cleaned.shape)
# Out:
# Before dropping outliers:  (21990, 7)

# %%
# Remove outliers in the column ConvertedCompYearly
# df_cleaned = df_cleaned[(df_cleaned.ConvertedCompYearly >= lower_bound) & (df_cleaned.ConvertedCompYearly <= upper_bound)]
df_cleaned = df_cleaned.drop(outliers.index)

# %%
print("After dropping outliers: ", df_cleaned.shape)
# Out:
# After dropping outliers:  (21739, 7)

# %%
# Box plot for the feature ConvertedCompYearly without outliers
df_with_outliers_dropped.ConvertedCompYearly.plot(kind="box", subplots=True, layout=(2, 7), figsize=(12, 8), sharex=False, sharey=False)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## Train-Test Split

# %%
# Label encoding for "MainBranch"
df_cleaned['MainBranch_encoded'] = df_cleaned.MainBranch.map({"I am a developer by profession": 1,
                                                              "I am not primarily a developer, but I write code sometimes " \
                                                              "as part of my work/studies": 2})
df_cleaned.drop(columns='MainBranch', inplace=True)

# %%
# Ordinal encoding for "Age"
age_map = {
    'Under 18 years old': 0,
    '18-24 years old': 1,
    '25-34 years old': 2,
    '35-44 years old': 3,
    '45-54 years old': 4,
    '55-64 years old': 5,
    '65 years or older': 6,
    '': np.nan
}

df_cleaned['Age_encoded'] = df_cleaned.Age.map(age_map)
df_cleaned.drop(columns='Age', inplace=True)

# %%
df_cleaned.columns
df_cleaned.RemoteWork.unique()
# Out:
# array(['Hybrid (some remote, some in-person)', 'Remote', 'In-person', nan],
#       dtype=object)

# %%
# Ordinal encoding for "EdLevel"
education_map = {
    'Primary/elementary school': 0,
    'Secondary school (e.g. American high school, German Realschule or Gymnasium, etc.)': 1,
    'Some college/university study without earning a degree': 2,
    'Associate degree (A.A., A.S., etc.)': 3,
    'Bachelor’s degree (B.A., B.S., B.Eng., etc.)': 4,
    'Master’s degree (M.A., M.S., M.Eng., MBA, etc.)': 5,
    'Professional degree (JD, MD, Ph.D, Ed.D, etc.)': 6,
    'Something else': np.nan
}

df_cleaned['EdLevel_encoded'] = df_cleaned.EdLevel.map(education_map)
df_cleaned.drop(columns='EdLevel', inplace=True)

# %%
# Split the data into features X and target y
y = df_cleaned.JobSat
X = df_cleaned.drop('JobSat', axis=1)

# Split the data into train and test datasets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)

# %%
# One-hot encoding for "Remote Work"
X_train_encoded = pd.get_dummies(X_train, columns=['RemoteWork'], prefix='RemoteWork', dummy_na=True)
X_test_encoded = pd.get_dummies(X_test, columns=['RemoteWork'], prefix='RemoteWork', dummy_na=True)

X_train_encoded
# Out:
#        ConvertedCompYearly        Country_simplified  MainBranch_encoded  \
# 49831                  NaN  United States of America                   1
# 32975              14000.0                     Other                   1
# 52395                  NaN                     India                   1
# 19575                  NaN                 Australia                   1
# 32194                  NaN                    Poland                   1
# ...                    ...                       ...                 ...
# 33956                  NaN  United States of America                   1
# 53396                  NaN               Switzerland                   1
# 24677                  NaN                     Other                   1
# 27542              47259.0                     Other                   1
# 6754               95796.0                 Australia                   1
#
#        Age_encoded  EdLevel_encoded  \
# 49831          4.0              2.0
# 32975          2.0              4.0
# 52395          3.0              5.0
# 19575          3.0              5.0
# 32194          2.0              2.0
# ...            ...              ...
# 33956          3.0              5.0
# 53396          3.0              5.0
# 24677          1.0              5.0
# 27542          2.0              2.0
# 6754           1.0              4.0
#
#        RemoteWork_Hybrid (some remote, some in-person)  RemoteWork_In-person  \
# 49831                                             True                 False
# 32975                                             True                 False
# 52395                                            False                 False
# 19575                                             True                 False
# 32194                                            False                 False
# ...                                                ...                   ...
# 33956                                            False                  True
# 53396                                            False                 False
# 24677                                            False                 False
# 27542                                             True                 False
# 6754                                              True                 False
#
#        RemoteWork_Remote  RemoteWork_nan
# 49831              False           False
# 32975              False           False
# 52395               True           False
# 19575              False           False
# 32194               True           False
# ...                  ...             ...
# 33956              False           False
# 53396               True           False
# 24677               True           False
# 27542              False           False
# 6754               False           False
#
# [17391 rows x 9 columns]

# %%
# Target encoding for feature "Country"
# Create Xy_train to create target mean
Xy_train = X_train.copy()
Xy_train['JobSat'] = y_train
mean_job_sat_train = Xy_train.groupby('Country_simplified')['JobSat'].mean()

# Encode X_train and X_test
X_train_encoded['Country_encoded'] = X_train_encoded.Country_simplified.map(mean_job_sat_train)
X_test_encoded['Country_encoded'] = X_test_encoded.Country_simplified.map(mean_job_sat_train)

# Drop the original column "Country"
X_train_encoded.drop(columns='Country_simplified', inplace=True)
X_test_encoded.drop(columns='Country_simplified', inplace=True)

X_train_encoded
# Out:
#        ConvertedCompYearly  MainBranch_encoded  Age_encoded  EdLevel_encoded  \
# 49831                  NaN                   1          4.0              2.0
# 32975              14000.0                   1          2.0              4.0
# 52395                  NaN                   1          3.0              5.0
# 19575                  NaN                   1          3.0              5.0
# 32194                  NaN                   1          2.0              2.0
# ...                    ...                 ...          ...              ...
# 33956                  NaN                   1          3.0              5.0
# 53396                  NaN                   1          3.0              5.0
# 24677                  NaN                   1          1.0              5.0
# 27542              47259.0                   1          2.0              2.0
# 6754               95796.0                   1          1.0              4.0
#
#        RemoteWork_Hybrid (some remote, some in-person)  RemoteWork_In-person  \
# 49831                                             True                 False
# 32975                                             True                 False
# 52395                                            False                 False
# 19575                                             True                 False
# 32194                                            False                 False
# ...                                                ...                   ...
# 33956                                            False                  True
# 53396                                            False                 False
# 24677                                            False                 False
# 27542                                             True                 False
# 6754                                              True                 False
#
#        RemoteWork_Remote  RemoteWork_nan  Country_encoded
# 49831              False           False         6.982148
# 32975              False           False         6.849432
# 52395               True           False         6.687595
# 19575              False           False         6.856757
# 32194               True           False         6.836957
# ...                  ...             ...              ...
# 33956              False           False         6.982148
# 53396               True           False         7.074468
# 24677               True           False         6.849432
# 27542              False           False         6.849432
# 6754               False           False         6.856757
#
# [17391 rows x 9 columns]

# %% [markdown]
# ## Feature Selection

# %% [markdown]
# ## Model Selection

# %% [markdown]
# ## Model Training & Evaluation

# %% [markdown]
# ## Evaluation
